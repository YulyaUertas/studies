# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Декомпозиция" data-toc-modified-id="Декомпозиция-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Декомпозиция</a></span></li><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Добавление-столбцов" data-toc-modified-id="Добавление-столбцов-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Добавление столбцов</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Считаем-количество-уникальных-пользователей,-использовавших-продукт-в-течении-дня-(DAU)" data-toc-modified-id="Считаем-количество-уникальных-пользователей,-использовавших-продукт-в-течении-дня-(DAU)-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Считаем количество уникальных пользователей, использовавших продукт в течении дня (DAU)</a></span></li><li><span><a href="#Анализируем-количество-новых-пользователей-каждый-день-(DNUA)" data-toc-modified-id="Анализируем-количество-новых-пользователей-каждый-день-(DNUA)-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Анализируем количество новых пользователей каждый день (DNUA)</a></span></li><li><span><a href="#Оцениваем-retention-rate" data-toc-modified-id="Оцениваем-retention-rate-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Оцениваем retention rate</a></span></li><li><span><a href="#Считаем-конверсии-для-новых-посетителей-посмотревших-контакты" data-toc-modified-id="Считаем-конверсии-для-новых-посетителей-посмотревших-контакты-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Считаем конверсии для новых посетителей посмотревших контакты</a></span></li><li><span><a href="#Оцениваем-длительность-сессии" data-toc-modified-id="Оцениваем-длительность-сессии-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Оцениваем длительность сессии</a></span></li><li><span><a href="#Посчитаем-среднее-число-сессий-на-пользователя-за-день" data-toc-modified-id="Посчитаем-среднее-число-сессий-на-пользователя-за-день-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Посчитаем среднее число сессий на пользователя за день</a></span></li><li><span><a href="#Анализируем-источники,-через-который-пользователь-&quot;пришёл&quot;-в-наше-приложение." data-toc-modified-id="Анализируем-источники,-через-который-пользователь-&quot;пришёл&quot;-в-наше-приложение.-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Анализируем источники, через который пользователь "пришёл" в наше приложение.</a></span><ul class="toc-item"><li><span><a href="#Оцениваем-retention-rate-для-источников" data-toc-modified-id="Оцениваем-retention-rate-для-источников-6.7.1"><span class="toc-item-num">6.7.1&nbsp;&nbsp;</span>Оцениваем retention rate для источников</a></span></li><li><span><a href="#Считаем-конверсию-для-разных-источников" data-toc-modified-id="Считаем-конверсию-для-разных-источников-6.7.2"><span class="toc-item-num">6.7.2&nbsp;&nbsp;</span>Считаем конверсию для разных источников</a></span></li></ul></li></ul></li><li><span><a href="#Основные-вопросы-исследования" data-toc-modified-id="Основные-вопросы-исследования-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Основные вопросы исследования</a></span><ul class="toc-item"><li><span><a href="#Проанализировать-связь-целевого-события-—-просмотра-контактов-—-и-других-действий-пользователей" data-toc-modified-id="Проанализировать-связь-целевого-события-—-просмотра-контактов-—-и-других-действий-пользователей-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Проанализировать связь целевого события — просмотра контактов — и других действий пользователей</a></span><ul class="toc-item"><li><span><a href="#В-разрезе-сессий-отобрать-сценарии\паттерны,-которые-приводят-к-просмотру-контактов" data-toc-modified-id="В-разрезе-сессий-отобрать-сценарии\паттерны,-которые-приводят-к-просмотру-контактов-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>В разрезе сессий отобрать сценарии\паттерны, которые приводят к просмотру контактов</a></span></li><li><span><a href="#Построить-воронки-по-основным-сценариям-в-разрезе-уникальных-пользователей;" data-toc-modified-id="Построить-воронки-по-основным-сценариям-в-разрезе-уникальных-пользователей;-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>Построить воронки по основным сценариям в разрезе уникальных пользователей;</a></span></li><li><span><a href="#Как-различается-длительность-сессий-с-contacts_show-и-без-него?" data-toc-modified-id="Как-различается-длительность-сессий-с-contacts_show-и-без-него?-7.1.3"><span class="toc-item-num">7.1.3&nbsp;&nbsp;</span>Как различается длительность сессий с contacts_show и без него?</a></span></li></ul></li><li><span><a href="#Оценить,-какие-действия-чаще-совершают-те-пользователи,-которые-просматривают-контакты:" data-toc-modified-id="Оценить,-какие-действия-чаще-совершают-те-пользователи,-которые-просматривают-контакты:-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Оценить, какие действия чаще совершают те пользователи, которые просматривают контакты:</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Одни-пользователи-совершают-действия-tips_show-и-tips_click-,-другие-—-только-tips_show-.-Проверить-гипотезу:-конверсия-в-просмотры-контактов-различается-у-этих-двух-групп;" data-toc-modified-id="Одни-пользователи-совершают-действия-tips_show-и-tips_click-,-другие-—-только-tips_show-.-Проверить-гипотезу:-конверсия-в-просмотры-контактов-различается-у-этих-двух-групп;-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Одни пользователи совершают действия tips_show и tips_click , другие — только tips_show . Проверить гипотезу: конверсия в просмотры контактов различается у этих двух групп;</a></span></li><li><span><a href="#Проверить-гипотезу:-конверсия-в-просмотры-контактов-вечерних-сессиий-(например-с-19:00-6:00)-выше,-чем-дневных-сессий" data-toc-modified-id="Проверить-гипотезу:-конверсия-в-просмотры-контактов-вечерних-сессиий-(например-с-19:00-6:00)-выше,-чем-дневных-сессий-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Проверить гипотезу: конверсия в просмотры контактов вечерних сессиий (например с 19:00-6:00) выше, чем дневных сессий</a></span></li><li><span><a href="#Проверить-гипотезу:-конверсия-пользователей-пришедших-с-Яндекса,-с-Гугл-и-других-источников-разная." data-toc-modified-id="Проверить-гипотезу:-конверсия-пользователей-пришедших-с-Яндекса,-с-Гугл-и-других-источников-разная.-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Проверить гипотезу: конверсия пользователей пришедших с Яндекса, с Гугл и других источников разная.</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Анализ поведения пользователей мобильного приложения <br/>           "Ненужные вещи"

# %% [markdown]
# ## Декомпозиция

# %% [markdown]
# 1) Цели исследования:
#
#  * Управление вовлеченностью клиентов (адаптация приложения по целевой и смежной аудитории) будет актуально только на основе данных о поведении пользователей;
#  * Получить на основе поведения пользователей гипотезы о том как можно было бы улучшить приложение с точки зрения пользовательского опыта.
#
#
# 2) Предобработка данных:
#
#  * Изучаем общую информацию о полученных датафреймах;
#  * Проверяем датафрейм на пропуски;
#  * Рассматриваем типы данных для каждого датафрейма. Для столбца со временем меняем тип данных;
#  * В столбце event.name событие show_contacts меняем на contacts_show, чтобы событие "посмотрел номер телефона" имело одно название;
#  * Переименуем названия столбов в стиле snake_case.
#  * Проверяем явные и неявные дубликаты.
#
# 3) Добавляем в таблицу новые столбцы со следующими параметрами:
#
#  * Столбец с номером сессии session_id;
#  * Столбец с длительностью сессии session_duration;
#  * Столбец с датой;
#  * Столбец с номером недели week;
#
# 4) Исследовательский анализ данных:
#
#  * Считаем количество уникальных пользователей, использовавших продукт в течении дня (DAU);
#  * Анализируем количество новых пользователей каждый день (DNUA);
#  * Оцениваем retention rate;
#  * Считаем конверсии для новых посетителей посмотревших контакты;
#  * Оцениваем длительность сессии;
#  * Посчитаем среднее число сессий на пользователя за день;
#  * Анализируем источники, через который пользователь "пришёл" в наше приложение.
#
# 5) Основные вопросы исследования:
#
#  * Проанализировать связь целевого события — просмотра контактов — и других действий пользователей:
#    - В разрезе сессий отобрать сценарии\паттерны, которые приводят к просмотру контактов;
#    - Построить воронки по основным сценариям в разрезе уникальных пользователей;
#    - Как различается длительность сессий с contacts_show и без него?
#
#  * Оценить, какие действия чаще совершают те пользователи, которые просматривают контакты:
#    - Рассчитать относительную частоту событий в разрезе двух групп пользователей - с contacts_show и без него.
#
#
# 6) Проверка гипотез:
#
#  * Одни пользователи совершают действия tips_show и tips_click , другие — только tips_show . Проверить гипотезу: конверсия в просмотры контактов различается у этих двух групп;
#  * Проверить гипотезу: конверсия в просмотры контактов вечерних сессиий (например с 19:00-6:00) выше, чем дневных сессий;
#  * Проверить гипотезу: конверсия пользователей пришедших с Яндекса, с Гугл и других источников разная.

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Мы аналитики мобильного приложения "Ненужные вещи". Мы должны провезти анализ поведения наших пользователей и ответить на следующие вопросы:
#
# 1. Проанализируйте связь целевого события — просмотра контактов — и других действий пользователей:
# - В разрезе сессий отобрать сценарии\паттерны, которые приводят к просмотру контактов
# - Построить воронки по основным сценариям в разрезе уникальных пользователей
# - Как различается длительность сессий с contacts_show и без него?
# 2. Оцените, какие действия чаще совершают те пользователи, которые просматривают контакты:
# - Рассчитать относительную частоту событий в разрезе двух групп пользователей - с contacts_show и без него.
#
# Описание данных:
#
# Датасет содержит данные о событиях, совершенных в мобильном приложении "Ненужные вещи". В нем пользователи продают свои ненужные вещи, размещая их на доске объявлений.
# В датасете содержатся данные пользователей, впервые совершивших действия в приложении после 7 октября 2019 года.
#
# Колонки в mobile_sources.csv:
#
# - userId — идентификатор пользователя,
# - source — источник, с которого пользователь установил приложение.
#
# Колонки в mobile_dataset.csv:
#
# - event.time — время совершения,
# - user.id — идентификатор пользователя,
# - event.name — действие пользователя.
#
# Виды действий:
# - advert_open — открыл карточки объявления,
# - photos_show — просмотрел фотографий в объявлении,
# - tips_show — увидел рекомендованные объявления,
# - tips_click — кликнул по рекомендованному объявлению,
# - contacts_show и show_contacts — посмотрел номер телефона,
# - contacts_call — позвонил по номеру из объявления,
# - map — открыл карту объявлений,
# - search_1 — search_7 — разные действия, связанные с поиском по сайту,
# - favorites_add — добавил объявление в избранное.

# %% [markdown]
# ## Загрузка данных

# %%
# загружаем все нужные библиотеки

import pandas as pd #
from datetime import datetime, timedelta #
import seaborn as sns #
import plotly.express as px #
from plotly import graph_objects as go #
from plotly.offline import iplot, init_notebook_mode #
from matplotlib import pyplot as plt #
import requests #
from tqdm import tqdm #
from scipy import stats as st #
import math as mth #
import warnings
warnings.filterwarnings('ignore')

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# загружаем файлы и сохраняем в переменные
dataset=pd.read_csv('https://code.s3.yandex.net/datasets/mobile_dataset.csv')
sources=pd.read_csv('https://code.s3.yandex.net/datasets/mobile_sources.csv')

# %%
dataset.head()
# Out:
#                    event.time   event.name  \
# 0  2019-10-07 00:00:00.431357  advert_open
# 1  2019-10-07 00:00:01.236320    tips_show
# 2  2019-10-07 00:00:02.245341    tips_show
# 3  2019-10-07 00:00:07.039334    tips_show
# 4  2019-10-07 00:00:56.319813  advert_open
#
#                                 user.id
# 0  020292ab-89bc-4156-9acf-68bc2783f894
# 1  020292ab-89bc-4156-9acf-68bc2783f894
# 2  cf7eda61-9349-469f-ac27-e5b6f5ec475c
# 3  020292ab-89bc-4156-9acf-68bc2783f894
# 4  cf7eda61-9349-469f-ac27-e5b6f5ec475c

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74197 entries, 0 to 74196
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   event.time  74197 non-null  object
#  1   event.name  74197 non-null  object
#  2   user.id     74197 non-null  object
# dtypes: object(3)
# memory usage: 1.7+ MB

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
print('Минимальная дата',dataset['event.time'].min())
print('Минимальная дата',dataset['event.time'].max())
# Out:
# Минимальная дата 2019-10-07 00:00:00.431357
# Минимальная дата 2019-11-03 23:58:12.532487

# %% [markdown]
# У нас есть датасет с данными пользователей, состоящий из 74197 строк и 3 колонок за период от 7 октября до 3 ноября. Нет пропусков и явных дубликатов. Для столбца event.name вид действий contacts_show заменим на show_contacts, чтобы не было никаких отличий. Для столбца event.time не обходимо изменить тип данных, а так же рассмотреть возможность удаления из даты и времени милисекунд.

# %%
sources.head()
# Out:
#                                  userId  source
# 0  020292ab-89bc-4156-9acf-68bc2783f894   other
# 1  cf7eda61-9349-469f-ac27-e5b6f5ec475c  yandex
# 2  8c356c42-3ba9-4cb6-80b8-3f868d0192c3  yandex
# 3  d9b06b47-0f36-419b-bbb0-3533e582a6cb   other
# 4  f32e1e2a-3027-4693-b793-b7b3ff274439  google

# %%
sources.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4293 entries, 0 to 4292
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userId  4293 non-null   object
#  1   source  4293 non-null   object
# dtypes: object(2)
# memory usage: 67.2+ KB

# %%
sources.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Второй датасет sources состоит из 4293 строк и двух столбов,не имеет дубликатов и типы данных соответсвуют столбцам. в нем изменим только название стоблца.

# %% [markdown]
# ## Предобработка данных

# %%
# изменим названия столбов для удобства
sources.columns=['user_id','source']
# проверяем
sources.head()
# Out:
#                                 user_id  source
# 0  020292ab-89bc-4156-9acf-68bc2783f894   other
# 1  cf7eda61-9349-469f-ac27-e5b6f5ec475c  yandex
# 2  8c356c42-3ba9-4cb6-80b8-3f868d0192c3  yandex
# 3  d9b06b47-0f36-419b-bbb0-3533e582a6cb   other
# 4  f32e1e2a-3027-4693-b793-b7b3ff274439  google

# %%
# изменим названия столбов для удобства
dataset.columns=['event_time','event_name','user_id']
# проверяем
dataset.head()
# Out:
#                    event_time   event_name  \
# 0  2019-10-07 00:00:00.431357  advert_open
# 1  2019-10-07 00:00:01.236320    tips_show
# 2  2019-10-07 00:00:02.245341    tips_show
# 3  2019-10-07 00:00:07.039334    tips_show
# 4  2019-10-07 00:00:56.319813  advert_open
#
#                                 user_id
# 0  020292ab-89bc-4156-9acf-68bc2783f894
# 1  020292ab-89bc-4156-9acf-68bc2783f894
# 2  cf7eda61-9349-469f-ac27-e5b6f5ec475c
# 3  020292ab-89bc-4156-9acf-68bc2783f894
# 4  cf7eda61-9349-469f-ac27-e5b6f5ec475c

# %%
# в столбце event_name вид действий contacts_show и show_contacts приводим к одному виду
dataset.loc[dataset['event_name']=='contacts_show', 'event_name']='show_contacts'

# %%
# в столбце event_name вид действия search_1 — search_7 поменяем на search, 
# так как эти действия обозначают одно и тоже

dataset['event_name'] = dataset['event_name'].str.replace('search_\d+','search', regex=True)

# %%
# проверяем
dataset['event_name'].unique()
# Out:
# array(['advert_open', 'tips_show', 'map', 'show_contacts', 'search',
#        'tips_click', 'photos_show', 'favorites_add', 'contacts_call'],
#       dtype=object)

# %%
# переводим event_time в формат data и удаляем милисекунды
dataset['event_time'] = pd.to_datetime(dataset['event_time']).dt.floor('s')
# проверим сколько появилось дубликатов

# %%
dataset.duplicated().sum()
# Out:
# 1224

# %%
round(dataset.duplicated().sum() * 100 / len(dataset) ,2)
# Out:
# 1.65

# %% [markdown]
# Если мы избавляемся от милисекунд, то у нас повляется всего 1,65 % дубликатов, или 1224 строчки. Работать с милисекундами будет неудобно, а удаление 1.65% датасета допустимо для анализа. Поэтому мы удалим эти строки из датасета.

# %%
dataset=dataset.drop_duplicates().reset_index(drop=True)

# %%
dataset.head()
# Out:
#            event_time   event_name                               user_id
# 0 2019-10-07 00:00:00  advert_open  020292ab-89bc-4156-9acf-68bc2783f894
# 1 2019-10-07 00:00:01    tips_show  020292ab-89bc-4156-9acf-68bc2783f894
# 2 2019-10-07 00:00:02    tips_show  cf7eda61-9349-469f-ac27-e5b6f5ec475c
# 3 2019-10-07 00:00:07    tips_show  020292ab-89bc-4156-9acf-68bc2783f894
# 4 2019-10-07 00:00:56  advert_open  cf7eda61-9349-469f-ac27-e5b6f5ec475c

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72973 entries, 0 to 72972
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   event_time  72973 non-null  datetime64[ns]
#  1   event_name  72973 non-null  object
#  2   user_id     72973 non-null  object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 1.7+ MB

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# После предработки данных датасет содержит 72973 строки, столбец event_time имеет тип данных datetime, пропусков и дубликатов нет.

# %% [markdown]
# ## Добавление столбцов

# %%
# добавляем столбец с датой
dataset['date']=dataset['event_time'].dt.date
dataset['date']=dataset['date'].astype("datetime64[ns]")
# добавляем столбец с номером недели (1-4)
dataset['week']=dataset['event_time'].dt.isocalendar().week

# %%
dataset.head()
# Out:
#            event_time   event_name                               user_id  \
# 0 2019-10-07 00:00:00  advert_open  020292ab-89bc-4156-9acf-68bc2783f894
# 1 2019-10-07 00:00:01    tips_show  020292ab-89bc-4156-9acf-68bc2783f894
# 2 2019-10-07 00:00:02    tips_show  cf7eda61-9349-469f-ac27-e5b6f5ec475c
# 3 2019-10-07 00:00:07    tips_show  020292ab-89bc-4156-9acf-68bc2783f894
# 4 2019-10-07 00:00:56  advert_open  cf7eda61-9349-469f-ac27-e5b6f5ec475c
#
#         date  week
# 0 2019-10-07    41
# 1 2019-10-07    41
# 2 2019-10-07    41
# 3 2019-10-07    41
# 4 2019-10-07    41

# %% [markdown]
# Столбцы с номером дня и недели добавлены.
#
# Чтобы добавить столбец с номером сесии, нужно назначить какой-то тайм-аут сессии. Для нашего сайта возьмем равным его 30 минут. Такой период используют [Яндекс Метрика](https://yandex.ru/support/metrica/general/glossary.html) и [Google Analytics](https://support.google.com/analytics/answer/9191807?hl=en) в своих сиситемах.

# %%
# сортируем датасет по пользователю и времени
dataset=dataset.sort_values(['user_id','event_time'])

# %%
# добавляем новый столбец с номером сессии
g = (dataset.groupby('user_id')['event_time'].diff() > pd.Timedelta('30Min')).cumsum()
dataset['session_id'] = dataset.groupby(['user_id', g], sort=False).ngroup() + 1
dataset.head(-5)
# Out:
#                event_time     event_name  \
# 791   2019-10-07 13:39:45      tips_show
# 792   2019-10-07 13:40:31      tips_show
# 795   2019-10-07 13:41:05      tips_show
# 806   2019-10-07 13:43:20      tips_show
# 815   2019-10-07 13:45:30      tips_show
# ...                   ...            ...
# 71349 2019-11-03 15:47:43      tips_show
# 71354 2019-11-03 15:48:05  show_contacts
# 71366 2019-11-03 15:50:01      tips_show
# 71376 2019-11-03 15:50:35      tips_show
# 71381 2019-11-03 15:50:56      tips_show
#
#                                     user_id       date  week  session_id
# 791    0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07    41           1
# 792    0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07    41           1
# 795    0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07    41           1
# 806    0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07    41           1
# 815    0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07    41           1
# ...

# %% [markdown]
# Добавляем столбец с продолжительностью сессии.

# %%
# соберем в другой датасет информацию о начале и конце сессии
dataset_dur=dataset.pivot_table(index={'session_id','user_id'}, values='event_time', aggfunc={'first','last'})

# посчитаем длительность сессии в секундах
dataset_dur['duration']=(dataset_dur['last']-dataset_dur['first']).dt.total_seconds()
dataset_dur = dataset_dur.rename_axis(None, axis=1).reset_index()
# посмотрим что получилось
dataset_dur.head()
# Out:
#                                 user_id  session_id               first  \
# 0  0001b1d5-b74a-4cbf-aeb0-7df5947bf349           1 2019-10-07 13:39:45
# 1  0001b1d5-b74a-4cbf-aeb0-7df5947bf349           2 2019-10-09 18:33:55
# 2  0001b1d5-b74a-4cbf-aeb0-7df5947bf349           3 2019-10-21 19:52:30
# 3  0001b1d5-b74a-4cbf-aeb0-7df5947bf349           4 2019-10-22 11:18:14
# 4  00157779-810c-4498-9e05-a1e9e3cedf93           5 2019-10-19 21:34:33
#
#                  last  duration
# 0 2019-10-07 13:49:41     596.0
# 1 2019-10-09 18:42:22     507.0
# 2 2019-10-21 20:07:30     900.0
# 3 2019-10-22 11:30:52     758.0
# 4 2019-10-19 21:59:54    1521.0

# %%
# объединим эти два датасета и оставим только нужные нам столбцы

dataset=dataset.merge(dataset_dur,on='session_id')
dataset=dataset[['event_time','event_name','user_id_x','date','week','session_id','duration']]
dataset.rename(columns={'user_id_x':'user_id'},inplace = True)
dataset.head()
# Out:
#            event_time event_name                               user_id  \
# 0 2019-10-07 13:39:45  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 1 2019-10-07 13:40:31  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 2 2019-10-07 13:41:05  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 3 2019-10-07 13:43:20  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 4 2019-10-07 13:45:30  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
#
#         date  week  session_id  duration
# 0 2019-10-07    41           1     596.0
# 1 2019-10-07    41           1     596.0
# 2 2019-10-07    41           1     596.0
# 3 2019-10-07    41           1     596.0
# 4 2019-10-07    41           1     596.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72973 entries, 0 to 72972
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   event_time  72973 non-null  datetime64[ns]
#  1   event_name  72973 non-null  object
#  2   user_id     72973 non-null  object
#  3   date        72973 non-null  datetime64[ns]
#  4   week        72973 non-null  UInt32
#  5   session_id  72973 non-null  int64
#  6   duration    72973 non-null  float64
# dtypes: UInt32(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 4.2+ MB

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Считаем количество уникальных пользователей, использовавших продукт в течении дня (DAU)

# %% [markdown]
# Под использованием продукта в течении дня будем понимать любое действие пользователя.

# %%
# гуппируем датасет по дате и считаем количество уникальных пользователей
tabl=dataset.groupby(by='date', as_index=False).agg({'user_id':'nunique'})
tabl.columns=['date','DAU']
tabl.head()
# Out:
#         date  DAU
# 0 2019-10-07  204
# 1 2019-10-08  204
# 2 2019-10-09  227
# 3 2019-10-10  233
# 4 2019-10-11  206

# %%
# строим график
fig=px.line(tabl,x='date',y='DAU',markers=True)
fig.update_layout(title='Количество уникальных пользователей, использовавших продукт в течении дня (DAU)',\
                 xaxis_title='Дата', yaxis_title='Количество пользователей')
fig.show()
# Out:
# <div>                            <div id="91c0ac6e-e28f-41aa-8d11-a760f4375a89" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91c0ac6e-e28f-41aa-8d11-a760f4375a89")) {                    Plotly.newPlot(                        "91c0ac6e-e28f-41aa-8d11-a760f4375a89",                        [{"hovertemplate":"date=%{x}<br>DAU=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":["2019-10-07T00:00:00","2019-10-08T00:00:00","2019-10-09T00:00:00","2019-10-10T00:00:00","2019-10-11T00:00:00","2019-10-12T00:00:00","2019-10-13T00:00:00","2019-10-14T00:00:00","2019-10-15T00:00:00","2019-10-16T00:00:00","2019-10-17T00:00:00","2019-
# ...

# %% [markdown]
# В первый день (7.10) в наше приложение зашли 204 пользователя. После небольшого роста, на 4 и 5 дни происходит падение и в день (12.10) в приложение заходит минимальное для нас 178 пользователей. По графику также можно сказать, что несмотря на некоторые падания, в целом, график рос. И максимального значения достиг 23 октября - 352 пользователя зашли в наше приложение в этот день. На последний день наблюдений (3 ноября), DAU после небольшого спада в предыдущии дни, опять начинает расти и достигает величины - 285 пользователя.

# %%
tabl[ '7day_rolling_avg' ] = tabl.DAU.rolling(7).mean()

plt.figure( figsize = ( 12, 5))

sns.lineplot( x = 'date',
             y = 'DAU',
             data = tabl,
             label = 'DAU')

sns.lineplot( x = 'date',
             y = '7day_rolling_avg',
             data = tabl,
             label = 'Скользящее среднее')
plt.xlabel('Дата')
plt.ylabel('Количество пользователей')
plt.title('Количество уникальных пользователей, использовавших продукт в течении дня (DAU)');

# %% [markdown]
# ### Анализируем количество новых пользователей каждый день (DNUA)

# %%
# сначала для каждого пользователя найдем дату первого использования приложения
table=dataset.groupby(by='user_id', as_index=False).agg({'event_time':'first'})
table['date']=table['event_time'].dt.date


# затем группируем получившуюся таблицу по дате и считаем количество новых пользователей каждый день
tabl=table.groupby(by='date', as_index=False).agg({'user_id':'nunique'})
tabl.columns=['date','DNUA']
tabl.head()
# Out:
#          date  DNUA
# 0  2019-10-07   204
# 1  2019-10-08   167
# 2  2019-10-09   176
# 3  2019-10-10   174
# 4  2019-10-11   136

# %%
# строим график
fig=px.line(tabl,x='date',y='DNUA',markers=True)
fig.update_layout(title='Количество новых пользователей каждый день (DNUA)',\
                 xaxis_title='Дата', yaxis_title='Количество пользователей')
fig.add_hline(y=155)
fig.show()
# Out:
# <div>                            <div id="694686e3-e1da-42c5-8e6c-22a882e58fbf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("694686e3-e1da-42c5-8e6c-22a882e58fbf")) {                    Plotly.newPlot(                        "694686e3-e1da-42c5-8e6c-22a882e58fbf",                        [{"hovertemplate":"date=%{x}<br>DNUA=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","orientation":"v","showlegend":false,"x":["2019-10-07","2019-10-08","2019-10-09","2019-10-10","2019-10-11","2019-10-12","2019-10-13","2019-10-14","2019-10-15","2019-10-16","2019-10-17","2019-10-18","2019-10-19","2019-10-20","2019-10-21","2019-10-22","2019-10-23","2019-10-24","2019-10-25",
# ...

# %% [markdown]
# По данному графику, мы видим что в целом график стремился к постоянному числу, но в конце периода наблюдения произошло снижение. Значит нужно работать над привлечением новых пользователей.

# %%
tabl[ '7day_rolling_avg' ] = tabl.DNUA.rolling(7).mean()

plt.figure( figsize = ( 12, 5))

sns.lineplot( x = 'date',
             y = 'DNUA',
             data = tabl,
             label = 'DNUA')

sns.lineplot( x = 'date',
             y = '7day_rolling_avg',
             data = tabl,
             label = 'Скользящее среднее')
plt.xlabel('Дата')
plt.ylabel('Количество пользователей')
plt.title('Количество новых пользователей каждый день (DNUA)');

# %% [markdown]
# ### Оцениваем retention rate

# %% [markdown]
# Сразу зададим:
#
# - момент анализа - 3.11 последний день наблюдений, чтобы получить как можно больше информации всего из месяца наблюдений
# - горизонт анализа - 14 дней, так как это максимальное количество дней, которые смогли "прожить" максимальное количество пользоваталей.

# %%
# задаём момент и горизонт анализа данных
observation_date = datetime(2019, 11, 3).date()
horizon_days = 14

# создаём опцию «игнорировать горизонт»
ignore_horizon = False

# %%
# для начала получаем профили пользователей
profiles=table.merge(sources,on='user_id')
profiles.columns=['user_id','first_ts','dt','source']
profiles['dt'] = pd.to_datetime(profiles['dt']).dt.date
profiles.head()
# Out:
#                                 user_id            first_ts          dt  \
# 0  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:39:45  2019-10-07
# 1  00157779-810c-4498-9e05-a1e9e3cedf93 2019-10-19 21:34:33  2019-10-19
# 2  00463033-5717-4bf1-91b4-09183923b9df 2019-11-01 13:54:35  2019-11-01
# 3  004690c3-5a84-4bb7-a8af-e0c8f8fca64e 2019-10-18 22:14:05  2019-10-18
# 4  00551e79-152e-4441-9cf7-565d7eb04090 2019-10-25 16:44:41  2019-10-25
#
#    source
# 0   other
# 1  yandex
# 2  yandex
# 3  google
# 4  yandex

# %%
# теперь к файлу с профилями добавим столбец с началом сессии и её продолжительностью из файла dataset_dur
session = profiles.merge(dataset_dur[['user_id', 'first','duration']], on='user_id', how='left')
session.columns=['user_id','first_ts','dt','source','session_start','duration']
#session['dt']=session['dt'].astype("datetime64[ns]")
session['dt'] = pd.to_datetime(session['dt']).dt.date
session.head()
# Out:
#                                 user_id            first_ts          dt  \
# 0  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:39:45  2019-10-07
# 1  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:39:45  2019-10-07
# 2  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:39:45  2019-10-07
# 3  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:39:45  2019-10-07
# 4  00157779-810c-4498-9e05-a1e9e3cedf93 2019-10-19 21:34:33  2019-10-19
#
#    source       session_start  duration
# 0   other 2019-10-07 13:39:45     596.0
# 1   other 2019-10-09 18:33:55     507.0
# 2   other 2019-10-21 19:52:30     900.0
# 3   other 2019-10-22 11:18:14     758.0
# 4  yandex 2019-10-19 21:34:33    1521.0

# %%
# рассчитываем максимально возможную дату привлечения
last_suitable_acquisition_date = observation_date
if not ignore_horizon:
    last_suitable_acquisition_date = observation_date - timedelta(
        days=horizon_days - 1
    )

# исключаем пользователей, пришедших после максимальной даты привлечения
result_raw = session.query('dt <= @last_suitable_acquisition_date')

# вычисляем лайфтайм каждой сессии в днях
result_raw['lifetime'] = (
    result_raw['session_start'] - result_raw['first_ts']
).dt.days

result_grouped = result_raw.pivot_table(
    index=['dt'], columns='lifetime', values='user_id', aggfunc='nunique'
)  # строим таблицу удержания

cohort_sizes = (
    result_raw.groupby('dt')
    .agg({'user_id': 'nunique'})
    .rename(columns={'user_id': 'cohort_size'})
)  # вычисляем размеры когорт

result_grouped = cohort_sizes.merge(
    result_grouped, on='dt', how='left'
).fillna(0)  # объединяем размеры когорт и таблицу удержания

# делим данные таблицы удержания на размеры когорт
result_grouped = result_grouped.div(result_grouped['cohort_size'], axis=0)

# исключаем из результата все лайфтаймы, превышающие горизонт анализа
result_grouped = result_grouped[['cohort_size'] + list(range(horizon_days))]

# во время деления все значения cohort_size превратились в единицу
# восстанавливаем — они понадобятся нам
result_grouped['cohort_size'] = cohort_sizes

# строим хэтмэп

plt.figure(figsize = (15, 6))  # задаём размер графика
sns.heatmap(result_grouped.drop(columns = ['cohort_size',0]), # удаляем размеры когорт
            annot = True,  # включаем подписи
            fmt = '.2%',  # отображаем значения в виде процентов
            )
plt.title('Тепловая карта удержания')  # название графика
plt.ylabel('Дата') 
plt.xlabel('Лайфтайм') 
plt.show()

# %% [markdown]
# По хэтмэпу видно, что лучшее удержание на первый день показывают пользователи, привлеченные 8 октября - 16%, на втрой день - 12,5%, что тоже хороший результат, но на третих день % удержанных пользователей падает больше чем в 2 раза - 5,3%.
#
# Для пользователей,привлеченных 12 октября удержание на второй день составляет 16%, а далее так же падение, но с 5 до 10 дня удержание для этих пользоватаелй выше, чем у привлеченных в другие дни.
#
# Самая "яркая полоса" для пользоваталей от 17 октября. Удержание для этих пользователей  в первый день составляло 14%, потом 12%, и далее еще 4 дня показатели были около 9%.
#
# Далее построим кривые удержания.

# %%
# строим кривые удержания

report = result_grouped.drop(columns = ['cohort_size', 0])

report.T.plot(
    grid=True,  # добавляем сетку
    xticks=list(report.columns.values),  # отметки на оси X — названия колонок
    figsize=(15, 5),  # размер графика
)
plt.xlabel('Лайфтайм')  # название оси X
plt.ylabel('Коэффициент удержания')
plt.title('Кривые удержания по дням привлечения') # название графика
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# По общему графику видно, что удержание практически для всех когорт имеет одинаковую тенденцию, хоть и есть несколько выбивающихся линий. Рассмотрим отдельно удержание для периода от 11 до 17 октября.

# %%
# строим кривые удержания

report = result_grouped.drop(columns = ['cohort_size', 0])

startdate = pd.to_datetime("2019-10-11").date()
enddate = pd.to_datetime("2019-10-17").date()

report.T.loc[:,startdate:enddate].plot(
    grid=True,  # добавляем сетку
    xticks=list(report.columns.values),  # отметки на оси X — названия колонок
    figsize=(15, 5),  # размер графика
)
plt.xlabel('Лайфтайм')  # название оси X
plt.ylabel('Коэффициент удержания')
plt.title('Кривые удержания по дням привлечения c 11 по 17 октября')  # название графика
plt.show()

# %% [markdown]
# По получившимся линиям, можно сделать следующие выводы:
# * У пользоваталей от 12 октября на второй день наблюдений был резкий скачок до 0.16, а потом не менее резкий спад, на третй день удержание ровнялось 0.05. Но с 5 по 10 день наблюдений удержание для этой когорты было выше, чеим у всех остальных;
# * У пользователей от 16 октября с первого по третий день удержание падало и достигло 0.03, далее увеличилось до 0.06, но не поднималось выше этого показателя на протяжении всего периода наблюдений;
# * Самое низкое удержание достигается у когорты от 11 октября на 8 день - менее 0.02. Что интересно, только у этой когорты именно в этот день удержание резко падает, когда у остальных либо увеличивается, либо остается прежним;
# * Когорта от 17 октября хоть и имеет некоторые спады, но практически на всем периоде имеет высокие показатели удержания.

# %%
# строим графики изменений

report = result_grouped.drop(columns=['cohort_size', 0])
#session['dt']=session['dt'].astype("datetime64[ns]")

report.plot(grid=True, figsize=(15, 5))
plt.xlabel('Дата привлечения')
plt.ylabel('Коэффициент удержания')
plt.title('Динамика удержания пользователей')
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# По общему графику видно, что удержание в 1 и 2 дни практически всегда выше, чем в другие, а далее происходит снижение, но в целом прктически у всех лайфтаймов одинаковая структура.

# %% [markdown]
# ### Считаем конверсии для новых посетителей посмотревших контакты

# %%
# выделяем только тех пользователей, которые посмотрели контакты
data_contacts = dataset.query('event_name == "show_contacts"')
data_contacts_2=data_contacts.pivot_table(index = 'user_id',values='event_time', aggfunc= 'first')

data_contacts_2=data_contacts_2.rename_axis(None, axis=1).reset_index()
data_contacts_2.columns=['user_id','event_dt']
orders=data_contacts_2
orders
# Out:
#                                   user_id            event_dt
# 0    00157779-810c-4498-9e05-a1e9e3cedf93 2019-10-20 19:17:18
# 1    00551e79-152e-4441-9cf7-565d7eb04090 2019-10-25 16:44:41
# 2    005fbea5-2678-406f-88a6-fbe9787e2268 2019-10-11 11:22:54
# 3    00753c79-ea81-4456-acd0-a47a23ca2fb9 2019-10-20 14:57:06
# 4    007d031d-5018-4e02-b7ee-72a30609173f 2019-10-22 13:08:09
# ..                                    ...                 ...
# 976  fee3ba1c-16f4-46f7-bf56-4bf80cc4e2f5 2019-10-26 12:13:19
# 977  ff1554b5-919e-40b1-90bb-ee1f7f6d5846 2019-10-21 10:59:23
# 978  ffc01466-fdb1-4460-ae94-e800f52eb136 2019-10-07 20:33:42
# 979  ffe68f10-e48e-470e-be9b-eeb93128ff1a 2019-10-22 16:07:17
# 980  fffb9e79-b927-4dbb-9b48-7fd09b23a62b 2019-10-16 12:57:40
#
# [981 rows x 2 columns]

# %%
# функция для расчета конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу конверсии
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        # считаем сумму с накоплением для каждой строки
        result = result.fillna(0).cumsum(axis = 1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # добавляем размеры когорт в таблицу конверсии
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# считаем конверсию
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days)

plt.figure(figsize = (15, 6))
    # строим хитмэп по таблице конверсии
sns.heatmap(conversion.drop(columns=['cohort_size']), annot=True, fmt='.2%')
plt.title('Тепловая карта конверсии без разбивки')
plt.ylabel('Величина конверсии') 
plt.xlabel('Лайфтайм') 
plt.xticks()

plt.show()

# %% [markdown]
# По тепловой карте, можно сделать вывод, что конверсия пользователей, посмотревших контакты увеличивается, что хорошо. Но за 14 дней наблюдений, прирост составляет всего 4%.

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.ylabel('Величина конверсии')

    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(index='dt', columns=columns, values=horizon - 1, aggfunc='mean')
    
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
# применяем функцию расчета и визуализации конверсии
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days )

plot_conversion(conversion, conversion_history, horizon_days)

# %% [markdown]
# Конверсия увеличивается, но не сильно. Необходимо работать над увеличением этого показателя.

# %% [markdown]
# ### Оцениваем длительность сессии

# %% [markdown]
# Мы уже использовали файл с сессиями, в котором в последнем столбце выражена их длительность в секундах. Посмотрим на него еще раз.

# %%
session.head()
# Out:
#                                 user_id            first_ts          dt  \
# 0  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:39:45  2019-10-07
# 1  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:39:45  2019-10-07
# 2  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:39:45  2019-10-07
# 3  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:39:45  2019-10-07
# 4  00157779-810c-4498-9e05-a1e9e3cedf93 2019-10-19 21:34:33  2019-10-19
#
#    source       session_start  duration
# 0   other 2019-10-07 13:39:45     596.0
# 1   other 2019-10-09 18:33:55     507.0
# 2   other 2019-10-21 19:52:30     900.0
# 3   other 2019-10-22 11:18:14     758.0
# 4  yandex 2019-10-19 21:34:33    1521.0

# %% [markdown]
# Посмотрим описание столбца с продолжительностью сессий и построим для него диаграму размаха.

# %%
dur_des=session['duration'].describe()
dur_des
# Out:
# count    10368.000000
# mean       772.672936
# std       1191.613451
# min          0.000000
# 25%         21.000000
# 50%        335.000000
# 75%       1046.000000
# max      19319.000000
# Name: duration, dtype: float64

# %%
session.boxplot()
plt.ylabel('Секунды')
plt.title('Диаграмма размаха для продолжительности сессий')
plt.tight_layout()
plt.show()

# %% [markdown]
# Из графика и описания видно, что есть сесии, длительность которых более 1,2,3 и даже 4 часов. Это не похоже на обычные сессии, медиальная длительность которых 5,6 минут. Из-за выбросов разница между медианной и средним очень большая - примерно 7 минут.
# Попробуем исключить, все сесии которые длятся больше, чем Q3+1,5IQR.

# %%
# считаем предельное число для продолжительности сессиий
predel=1.5*(dur_des[6]-dur_des[4])+dur_des[6]

# %%
print ('Предельное значение =', predel)
print('Процент сессии, длительность которых больше или равна предельному значению:',\
      round((session.query('duration >= @predel')['user_id'].count() * 100)/session['user_id'].count(),2),'%')
# Out:
# Предельное значение = 2583.5
# Процент сессии, длительность которых больше или равна предельному значению: 6.57 %

# %%
session_analysis=session.loc[session['duration']<predel]
session_analysis.describe()
# Out:
#           duration
# count  9687.000000
# mean    534.072881
# std     632.585723
# min       0.000000
# 25%      10.000000
# 50%     282.000000
# 75%     840.000000
# max    2582.000000

# %% [markdown]
# Мы видим, что исключив 7% сессий, разница между средним и мидиальным значениями будет ровнятся уже 4 минутам. И тогда средняя продолжительность сессии ровняется 8,75 минут.
#
# Также можно посмотреть, как меняется средняя продолжительность сесиий в зависимости от дня недели.

# %%
# добавляем столбец с днем недели
session_analysis['session_day']=session_analysis['session_start'].dt.day_name()
session_analysis['session_day_num']=session_analysis['session_start'].dt.weekday

# %%
session_analysis.pivot_table(index={'session_day','session_day_num'}, values='duration',aggfunc='mean')\
.sort_values('session_day_num').plot(kind='bar',ylim=(450,560),grid=True)

plt.xlabel('Дни недели')
plt.title('Средняя прододжительность сессии по дням недели')
plt.xlabel('Дни недели')
plt.xticks(rotation=45)
plt.ylabel('Секунды');

# %% [markdown]
# Из графика видно, что самые длительные сессии бывают в воскресенье и  понедельникик - 550 секунд, а в среду и четверг средняя продолжительность падает и ровняется примерно 500 секунд.

# %% [markdown]
# ### Посчитаем среднее число сессий на пользователя за день

# %%
print('Среднее число сессий на пользователя за день =',round(session_analysis.pivot_table(index='dt', values='user_id',aggfunc='count')['user_id'].mean()))
# Out:
# Среднее число сессий на пользователя за день = 346

# %%
# добавляем столбик с днем месяца
session_analysis['session_start_dt']=session_analysis['session_start'].dt.date

# %%
# строим график отражающий среднее число сессии на каждый день
session_analysis.pivot_table(index='session_start_dt', values='user_id',aggfunc='count')\
.plot(kind='bar',grid=True,ylim=(200,450), figsize=(10,5))
plt.axhline (y=334,color='red', linestyle='--')
plt.xlabel('Дата')
plt.ylabel('Количество сессий')
plt.title('Среднее число сессии на каждый день');

# %% [markdown]
# В начале запуска приложения в день в среднем было около 250 сессии. В первый и 6 день сессий было еще меньше - 210-220. После недельного использования приложения сессий стало больше и практически на всем периоде это число выше среднего. Так же по графику видны недельные "ритмы", как и для средней продолжительности, т.е. в среду и четверг самые низкие показателя, далее они растут к выходным и во вторник происходит уменьшение.

# %% [markdown]
# ### Анализируем источники, через который пользователь "пришёл" в наше приложение.

# %%
# рассмотрим файл с источниками
sources.head()
# Out:
#                                 user_id  source
# 0  020292ab-89bc-4156-9acf-68bc2783f894   other
# 1  cf7eda61-9349-469f-ac27-e5b6f5ec475c  yandex
# 2  8c356c42-3ba9-4cb6-80b8-3f868d0192c3  yandex
# 3  d9b06b47-0f36-419b-bbb0-3533e582a6cb   other
# 4  f32e1e2a-3027-4693-b793-b7b3ff274439  google

# %%
# посчитаем, сколько пользователей пришло из каждого источника
sources.pivot_table(index='source',values='user_id',aggfunc='nunique')\
.plot(kind='pie',y='user_id',autopct='%1.1f%%',legend=False)
plt.ylabel('')
plt.title('Количество пользователей пришедших из разных источников');

# %% [markdown]
# Пользователей, пришедших из яндекса практически в 2 раза больше чем, пользователей пришедших из гугла и других - 45%. Меньше всего пришло из гугл - 26%. Посомтрим, какое удержание и конверсия для пользователей пришедших из разных источников.

# %% [markdown]
# ####  Оцениваем retention rate для источников

# %% [markdown]
# Применим функцию для расчета удержания с разделениям по источникам

# %%
# функция для расчёта удержания

def get_retention(
    result_raw,
    observation_date,
    horizon_days,
    dimensions=[],  
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = result_raw.query('dt <= @last_suitable_acquisition_date')

    
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # рассчитываем удержание
    # новый вариант с dimensions
    result_grouped = result_raw.pivot_table(
        index=dimensions,  # заменили dt
        columns='lifetime',
        values='user_id',
        aggfunc='nunique',
    )
    cohort_sizes = (
        result_raw.groupby(dimensions)  # заменили dt
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'cohort_size'})
    )
    result_grouped = cohort_sizes.merge(
        result_grouped, on=dimensions, how='left'  # заменили dt
    ).fillna(0)
    result_grouped = result_grouped.div(result_grouped['cohort_size'], axis=0)

    # исключаем все лайфтаймы, превышающие горизонт анализа
    result_grouped = result_grouped[
        ['cohort_size'] + list(range(horizon_days))
    ]

    # восстанавливаем столбец с размерами когорт
    result_grouped['cohort_size'] = cohort_sizes
    
    
    
    # возвращаем таблицу удержания и сырые данные
    return result_raw, result_grouped

# %%
# рассчитываем удержание с учётом источника

retention_raw, retention = get_retention(
    session, observation_date, horizon_days, dimensions=['source']
)  

report = retention.drop(columns=['cohort_size', 0])
report.T.plot(grid=True, xticks=list(report.columns.values), figsize=(15, 5))
plt.xlabel('Лайфтайм')
plt.ylabel('Коэффициент удержания')
plt.title('Кривые удержания с разбивкой по источникам')
plt.show()

# %% [markdown]
# Как видно из графика, удержание для всех источников практически идентично. Но для гугл и других на протяжении всего дайфтайма идет практически зеркальное отражение показателя удержания: например на 5 дне, у гугл показатель ровнялся 0.045, а у других - 0.08, но далее ситуация изменилась и например на 7 дней у гугл 0.07, а у других - 0.055. Яндекс же практически всегда имеет усредненный показатель между двумя другими.

# %% [markdown]
# #### Считаем конверсию для разных источников

# %%
# применяем функцию для расчета конверсии
conversion_raw, conversion, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['source'])
# применяем функцию для визуализации конверсии
plot_conversion(conversion, conversion_history, horizon_days)

# %% [markdown]
# Графики конверсий имеют идентичную структуру, но как видно самые лучшие показатели у пользователей, пришедших через яндекс, на 14 день конверсия чуть выше 0.24. У пользователей гугл конверсия ниже и на 14 день примерно ровна 0.22. У пользователей пришедших через другие источники конверсия сильно ниже, на 14 день этот показатель достигает всего лишь 0.19.
#
# В целом по источникам, можно сделать вывод, что больше всего пользователей приходят через яндекс, и для этих пользователей хорошая конверсия и удержание. Гугл и другие источнники привлекли практически одинаковое количество людей, в целом их удержание схоже с яндексом, но конверсия хуже.

# %% [markdown]
# ## Основные вопросы исследования

# %% [markdown]
# ### Проанализировать связь целевого события — просмотра контактов — и других действий пользователей

# %% [markdown]
# В этом разделе нам нужно произвести следующие действия:
#    - В разрезе сессий отобрать сценарии\паттерны, которые приводят к просмотру контактов;
#    - Построить воронки по основным сценариям в разрезе уникальных пользователей;
#    - Как различается длительность сессий с contacts_show и без него?

# %% [markdown]
# #### В разрезе сессий отобрать сценарии\паттерны, которые приводят к просмотру контактов

# %% [markdown]
# Для нахождения сценариев построим диаграму Сэнкея. Для этого из файла dataset необходимо избавиться от повторяющихся событий в сессиях. Посчитаем сколько таких событий и удалим их. А также оставим только столбцы с нужными нам столбцами.

# %%
dataset.head(10)
# Out:
#            event_time event_name                               user_id  \
# 0 2019-10-07 13:39:45  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 1 2019-10-07 13:40:31  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 2 2019-10-07 13:41:05  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 3 2019-10-07 13:43:20  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 4 2019-10-07 13:45:30  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 5 2019-10-07 13:45:43  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 6 2019-10-07 13:46:31  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 7 2019-10-07 13:47:32  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 8 2019-10-07 13:49:41  tips_show  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 9 2019-10-09 18:33:55        map  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
#
#         date  week  session_id  duration
# 0 2019-10-07    41           1     596.0
# 1 2019-10-07    41           1     596.0
# 2 2019-10-07    41           1     596.0
# ...

# %%
print('Количество дубликатов:',dataset.duplicated(['session_id','user_id','event_name']).sum())
# Out:
# Количество дубликатов: 55119

# %%
# удаляем дубликаты
dataset_sankey=dataset.drop_duplicates(['session_id','user_id','event_name']).reset_index()
# оставляем нужные нам столбцы
dataset_sankey=dataset_sankey[['session_id','event_time','event_name','user_id','duration']]

# %%
dataset_sankey.head(10)
# Out:
#    session_id          event_time   event_name  \
# 0           1 2019-10-07 13:39:45    tips_show
# 1           2 2019-10-09 18:33:55          map
# 2           2 2019-10-09 18:40:28    tips_show
# 3           3 2019-10-21 19:52:30    tips_show
# 4           3 2019-10-21 19:53:38          map
# 5           4 2019-10-22 11:18:14          map
# 6           4 2019-10-22 11:19:10    tips_show
# 7           5 2019-10-19 21:34:33       search
# 8           5 2019-10-19 21:40:38  photos_show
# 9           6 2019-10-20 18:49:24       search
#
#                                 user_id  duration
# 0  0001b1d5-b74a-4cbf-aeb0-7df5947bf349     596.0
# 1  0001b1d5-b74a-4cbf-aeb0-7df5947bf349     507.0
# 2  0001b1d5-b74a-4cbf-aeb0-7df5947bf349     507.0
# 3  0001b1d5-b74a-4cbf-aeb0-7df5947bf349     900.0
# 4  0001b1d5-b74a-4cbf-aeb0-7df5947bf349     900.0
# 5  0001b1d5-b74a-4cbf-aeb0-7df5947bf349     758.0
# 6  0001b1d5-b74a-4cbf-aeb0-7df5947bf349     758.0
# ...

# %% [markdown]
# Если сравнивать первые 10 строчек датасетов, то легко заметить, что удаление прошло верно.

# %%
def add_features(df):
    
    """Функция генерации новых столбцов для исходной таблицы

    Args:
        df (pd.DataFrame): исходная таблица.
    Returns:
        pd.DataFrame: таблица с новыми признаками.
    """
    
    # сортируем по id и времени
    sorted_df = df.sort_values(by=['session_id', 'event_time']).copy()
    # добавляем шаги событий
    sorted_df['step'] = sorted_df.groupby('session_id').cumcount() + 1
    
    # добавляем узлы-источники и целевые узлы
    # узлы-источники - это сами события
    sorted_df['source'] = sorted_df['event_name']
    # добавляем целевые узлы
    sorted_df['target'] = sorted_df.groupby('session_id')['source'].shift(-1)
    
    # возврат таблицы без имени событий
    return sorted_df.drop(['event_name'], axis=1)
  
# преобразуем таблицу
table = add_features(dataset_sankey)
table.head(5)
# Out:
#    session_id          event_time                               user_id  \
# 0           1 2019-10-07 13:39:45  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 1           2 2019-10-09 18:33:55  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 2           2 2019-10-09 18:40:28  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 3           3 2019-10-21 19:52:30  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 4           3 2019-10-21 19:53:38  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
#
#    duration  step     source     target
# 0     596.0     1  tips_show        NaN
# 1     507.0     1        map  tips_show
# 2     507.0     2  tips_show        NaN
# 3     900.0     1  tips_show        map
# 4     900.0     2        map        NaN

# %% [markdown]
# Нам нужно выбрать количество шагов для будущей диаграмы. Для этого построим распределение этой величины.

# %%
table.pivot_table(index='session_id',values='step', aggfunc='max')['step'].hist()
plt.xlabel('Шаги')
plt.ylabel('Количество сессий')
plt.title('Распределение количества шагов сессий');

# %%
y=table.groupby('session_id')[['step']].max()
y=y.rename_axis(None, axis=1).reset_index()
y=y.pivot_table(index='step',values='session_id',aggfunc='count')
y=y.rename_axis(None, axis=1).reset_index()
y['%']=round(y['session_id']*100/y['session_id'].sum(),2)
y= y[['step','%']]
y
# Out:
#    step      %
# 0     1  51.04
# 1     2  31.42
# 2     3  12.68
# 3     4   4.05
# 4     5   0.74
# 5     6   0.06

# %% [markdown]
# Как видно из рисунка и таблицы, максимальное количество шагов = 6, но пяти- и шестиэтапных сессий очень мало - меньше процента. Поэтому для построения диаграмы будем использовать сессии с 4-мя шагами.

# %%
# выделяем только 4-х ступенчатые сессии
df_comp = table[table['step'] <= 4].copy().reset_index(drop=True)

# %%
def get_source_index(df):
    
    """Функция генерации индексов source

    Args:
        df (pd.DataFrame): исходная таблица с признаками step, source, target.
    Returns:
        dict: словарь с индексами, именами и соответсвиями индексов именам source.
    """
    
    res_dict = {}
    
    count = 0
    # получаем индексы источников
    for no, step in enumerate(df['step'].unique().tolist()):
        # получаем уникальные наименования для шага
        res_dict[no+1] = {}
        res_dict[no+1]['sources'] = df[df['step'] == step]['source'].unique().tolist()
        res_dict[no+1]['sources_index'] = []
        for i in range(len(res_dict[no+1]['sources'])):
            res_dict[no+1]['sources_index'].append(count)
            count += 1
            
    # соединим списки
    for key in res_dict:
        res_dict[key]['sources_dict'] = {}
        for name, no in zip(res_dict[key]['sources'], res_dict[key]['sources_index']):
            res_dict[key]['sources_dict'][name] = no
    return res_dict

# %%
source_indexes = get_source_index(df_comp)

# %%
def generate_random_color():
    
    """Случайная генерация цветов rgba

    Args:
        
    Returns:
        str: Строка со сгенерированными параметрами цвета
    """
    
    # сгенерим значение для каждого канала
    r, g, b = np.random.randint(255, size=3)
    return f'rgba({r}, {g}, {b}, 1)'

# %%
def colors_for_sources(mode):
    
    """Генерация цветов rgba

    Args:
        mode (str): сгенерировать случайные цвета, если 'random', а если 'custom' - 
                    использовать заранее подготовленные
    Returns:
        dict: словарь с цветами, соответствующими каждому индексу
    """
    # словарь, в который сложим цвета в соответствии с индексом
    colors_dict = {}
    
    if mode == 'random':
        # генерим случайные цвета
        for label in df_comp['source'].unique():
            r, g, b = np.random.randint(255, size=3)            
            colors_dict[label] = f'rgba({r}, {g}, {b}, 1)'
            
    elif mode == 'custom':
        # присваиваем ранее подготовленные цвета
        colors = requests.get('https://raw.githubusercontent.com/rusantsovsv/senkey_tutorial/main/json/colors_senkey.json').json()
        for no, label in enumerate(df_comp['source'].unique()):
            colors_dict[label] = colors['custom_colors'][no]
            
    return colors_dict
  
  
colors_dict = colors_for_sources(mode='custom')

# %%
def percent_users(sources, targets, values):
    
    """
    Расчет уникальных id в процентах (для вывода в hover text каждого узла)
    
    Args:
        sources (list): список с индексами source.
        targets (list): список с индексами target.
        values (list): список с "объемами" потоков.
        
    Returns:
        list: список с "объемами" потоков в процентах
    """
    
    # объединим источники и метки и найдем пары
    zip_lists = list(zip(sources, targets, values))
    
    new_list = []
    
    # подготовим список словарь с общим объемом трафика в узлах
    unique_dict = {}
    
    # проходим по каждому узлу
    for source, target, value in zip_lists:
        if source not in unique_dict:
            # находим все источники и считаем общий трафик
            unique_dict[source] = 0
            for sr, tg, vl in zip_lists:
                if sr == source:
                    unique_dict[source] += vl
                    
    # считаем проценты
    for source, target, value in zip_lists:
        new_list.append(round(100 * value / unique_dict[source], 1))
    
    return new_list

# %%
def lists_for_plot(source_indexes=source_indexes, colors=colors_dict, frac=10):
    
    """
    Создаем необходимые для отрисовки диаграммы переменные списков и возвращаем
    их в виде словаря
    
    Args:
        source_indexes (dict): словарь с именами и индексами source.
        colors (dict): словарь с цветами source.
        frac (int): ограничение на минимальный "объем" между узлами.
        
    Returns:
        dict: словарь со списками, необходимыми для диаграммы.
    """
    
    sources = []
    targets = []
    values = []
    labels = []
    link_color = []
    link_text = []

    # проходим по каждому шагу
    for step in tqdm(sorted(df_comp['step'].unique()), desc='Шаг'):
        if step + 1 not in source_indexes:
            continue

        # получаем индекс источника
        temp_dict_source = source_indexes[step]['sources_dict']

        # получаем индексы цели
        temp_dict_target = source_indexes[step+1]['sources_dict']

        # проходим по каждой возможной паре, считаем количество таких пар
        for source, index_source in tqdm(temp_dict_source.items()):
            for target, index_target in temp_dict_target.items():
                # делаем срез данных и считаем количество id            
                temp_df = df_comp[(df_comp['step'] == step)&(df_comp['source'] == source)&(df_comp['target'] == target)]
                value = len(temp_df)
                # проверяем минимальный объем потока и добавляем нужные данные
                if value > frac:
                    sources.append(index_source)
                    targets.append(index_target)
                    values.append(value)
                    # делаем поток прозрачным для лучшего отображения
                    link_color.append(colors[source].replace(', 1)', ', 0.2)'))
                    
    labels = []
    colors_labels = []
    for key in source_indexes:
        for name in source_indexes[key]['sources']:
            labels.append(name)
            colors_labels.append(colors[name])
            
    # посчитаем проценты всех потоков
    perc_values = percent_users(sources, targets, values)
    
    # добавим значения процентов для howertext
    link_text = []
    for perc in perc_values:
        link_text.append(f"{perc}%")
    
    # возвратим словарь с вложенными списками
    return {'sources': sources, 
            'targets': targets, 
            'values': values, 
            'labels': labels, 
            'colors_labels': colors_labels, 
            'link_color': link_color, 
            'link_text': link_text}
  

# создаем словарь
data_for_plot = lists_for_plot()
# Out:
# ...
# Шаг: 100%|████████████████████████████████████████| 4/4 [00:00<00:00,  5.30it/s]

# %%
def plot_senkey_diagram(data_dict=data_for_plot):    
    
    """
    Функция для генерации объекта диаграммы Сенкей 
    
    Args:
        data_dict (dict): словарь со списками данных для построения.
        
    Returns:
        plotly.graph_objs._figure.Figure: объект изображения.
    """
    fig = go.Figure(data=[go.Sankey(
        domain = dict(
          x =  [0,1],
          y =  [0,1]
        ),
        orientation = "h",
        valueformat = ".0f",
        node = dict(
          pad = 50,
          thickness = 15,
          line = dict(color = "black", width = 0.1),
          label = data_dict['labels'],
          color = data_dict['colors_labels']
        ),
        link = dict(
          source = data_dict['sources'],
          target = data_dict['targets'],
          value = data_dict['values'],
          label = data_dict['link_text'],
          color = data_dict['link_color']
      ))])
    fig.update_layout(title_text="Sankey Diagram", font_size=10,autosize=True)
    # возвращаем объект диаграммы
    return fig
  
# сохраняем диаграмму в переменную
senkey_diagram = plot_senkey_diagram()

# %%
senkey_diagram.show()
# Out:
# <div>                            <div id="46d27d9f-ca82-4fdf-a0f2-92436e20b7da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46d27d9f-ca82-4fdf-a0f2-92436e20b7da")) {                    Plotly.newPlot(                        "46d27d9f-ca82-4fdf-a0f2-92436e20b7da",                        [{"domain":{"x":[0,1],"y":[0,1]},"link":{"color":["rgba(42, 157, 143, 0.2)","rgba(42, 157, 143, 0.2)","rgba(42, 157, 143, 0.2)","rgba(42, 157, 143, 0.2)","rgba(42, 157, 143, 0.2)","rgba(42, 157, 143, 0.2)","rgba(38, 70, 83, 0.2)","rgba(38, 70, 83, 0.2)","rgba(38, 70, 83, 0.2)","rgba(38, 70, 83, 0.2)","rgba(233, 196, 106, 0.2)","rgba(233, 196, 106, 0.2)","rgba(233, 196, 106, 0.2)","rgba(233, 196, 106, 0.2)","rgba(233, 196, 106, 0.2)","rgba(233, 196, 106, 0.2)","rgb
# ...

# %%
# диаграма откроется в новой вкладке
senkey_diagram.write_html('demo_senkey.html', auto_open=True)

# %% [markdown]
# Из всех сценариваев приводящих к целевому событию выберим следующие три:
#
# - map - tips_show - show_contacts
# - search - photos_show - show_contacts
# - map - advert_open - tips_show - show_contacts

# %% [markdown]
# #### Построить воронки по основным сценариям в разрезе уникальных пользователей;

# %% [markdown]
# Для каждого сценария построим воронку, для этого будем использовать файл df_comp и оставим в нем только действия из сценариев.

# %% [markdown]
# __Cтроим первую воронку - map - tip_show - show_contacts__

# %%
# действия из первого сценария
steps=['map','tips_show','show_contacts']
dataset_funnel=df_comp.query('source == @steps')
dataset_funnel.head(5)
# Out:
#    session_id          event_time                               user_id  \
# 0           1 2019-10-07 13:39:45  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 1           2 2019-10-09 18:33:55  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 2           2 2019-10-09 18:40:28  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 3           3 2019-10-21 19:52:30  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 4           3 2019-10-21 19:53:38  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
#
#    duration  step     source     target
# 0     596.0     1  tips_show        NaN
# 1     507.0     1        map  tips_show
# 2     507.0     2  tips_show        NaN
# 3     900.0     1  tips_show        map
# 4     900.0     2        map        NaN

# %%
# найдем для каждой сессии первое действие
st1=dataset_funnel.pivot_table(index='session_id',values='source',aggfunc='first')\
.rename_axis(None, axis=1).reset_index(level = None)
# сессии у которых первым шагом был map сохраним в список
st1=st1.query('source=="map"')['session_id'].tolist()
# посчитаем количество уникальных пользователей для которых первое действие map
step_1=dataset_funnel.query('session_id == @st1')['user_id'].nunique()
# сохраним только те сессии для которых первый был map в таблицу и удалим строки с действием map
dataset_funnel_2=dataset_funnel.query('session_id == @st1').query('source != "map"')

# найдем для каждой сессии следующее действие
st2=dataset_funnel_2.pivot_table(index='session_id',values='source',aggfunc='first')\
.rename_axis(None, axis=1).reset_index(level = None)
# сессии у которых вторым шагом был tips_show сохраним в список
st2=st2.query('source=="tips_show"')['session_id'].tolist()
# посчитаем количество уникальных пользователей для которых второе действие tips_show
step_2=dataset_funnel_2.query('session_id == @st2')['user_id'].nunique()
# сохраним только те сессии для которых вторым был tips_show в таблицу и удалим строки с действием tips_show
dataset_funnel_3=dataset_funnel_2.query('session_id == @st2').query('source != "tips_show"')

# посчитаем количество уникальных пользователей для которых третье действие show_contacts
step_3=dataset_funnel_3['user_id'].nunique()

# %%
# строим воронку событий и считаем долю пользователей,которые проходят на следующий шаг воронки
fig = go.Figure(go.Funnel(
    y = ["map", "tip_show", "show_contacts"],
    x = [step_1, step_2, step_3], textposition = "inside" ,textinfo = "value+percent previous")
               )
fig.update_layout(title='Воронка событий: map - tip_show - show_contacts')
fig.show();
# Out:
# <div>                            <div id="1f165642-0c6e-439b-9e8e-9441c145cb9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f165642-0c6e-439b-9e8e-9441c145cb9e")) {                    Plotly.newPlot(                        "1f165642-0c6e-439b-9e8e-9441c145cb9e",                        [{"textinfo":"value+percent previous","textposition":"inside","x":[1149,978,110],"y":["map","tip_show","show_contacts"],"type":"funnel"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay",
# ...

# %% [markdown]
# Пользователей, открывших сначала карту было 1149, из них на второй шаг - "увидел рекомендованое объявление" было 978, из них 11% перешли на последний шаг - просмотр контактов. Если смотреть только на первый и последний шаги - то 9,5% от первоначальных пользователей перешли в целевое действие - 110 пользователя.

# %% [markdown]
# __Cтроим вторую воронку search - photos_show - show_contacts__

# %%
steps=['show_contacts','search','photos_show']
dataset_funnel=df_comp.query('source == @steps')

# %%
st1=dataset_funnel.pivot_table(index='session_id',values='source',aggfunc='first')\
.rename_axis(None, axis=1).reset_index(level = None)
st1=st1.query('source=="search"')['session_id'].tolist()
step_1=dataset_funnel.query('session_id == @st1')['user_id'].nunique()
dataset_funnel_2=dataset_funnel.query('session_id == @st1').query('source != "search"')

st2=dataset_funnel_2.pivot_table(index='session_id',values='source',aggfunc='first')\
.rename_axis(None, axis=1).reset_index(level = None)
st2=st2.query('source=="photos_show"')['session_id'].tolist()
step_2=dataset_funnel_2.query('session_id == @st2')['user_id'].nunique()
dataset_funnel_3=dataset_funnel_2.query('session_id == @st2').query('source != "photos_show"')

step_3=dataset_funnel_3['user_id'].nunique()

# %%
# строим воронку событий и считаем долю пользователей,которые проходят на следующий шаг воронки
fig = go.Figure(go.Funnel(
    y = ["search", "photos_show", "show_contacts"],
    x = [step_1, step_2, step_3], textposition = "inside" ,textinfo = "value+percent previous")
               )
fig.update_layout(title='Воронка событий: map - tip_show - show_contacts')
fig.show();
# Out:
# <div>                            <div id="9fcaab8a-d72c-4610-9c21-423fcd01c9df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fcaab8a-d72c-4610-9c21-423fcd01c9df")) {                    Plotly.newPlot(                        "9fcaab8a-d72c-4610-9c21-423fcd01c9df",                        [{"textinfo":"value+percent previous","textposition":"inside","x":[1566,460,57],"y":["search","photos_show","show_contacts"],"type":"funnel"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"over
# ...

# %% [markdown]
# По второму сценарию относительные величины ниже. На первом этапе "разные действия, связанные с поиском по сайту" было больше пользователей, чем в первой воронке - 1566. На втрой этап - промотр фотографий перешло только 29% или 460 пользователей, из них 12% перешло на целевой этап - 57 пользователь.

# %% [markdown]
# __Cтроим третью воронку map - advert_open - tips_show - show_contacts__

# %%
steps=['show_contacts','map','advert_open','tips_show']
dataset_funnel=df_comp.query('source == @steps')

# %%
# строим третью воронку map - advert_open - tips_show - show_contacts

st1=dataset_funnel.pivot_table(index='session_id',values='source',aggfunc='first')\
.rename_axis(None, axis=1).reset_index(level = None)
st1=st1.query('source=="map"')['session_id'].tolist()
step_1=dataset_funnel.query('session_id == @st1')['user_id'].nunique()
dataset_funnel_2=dataset_funnel.query('session_id == @st1').query('source != "map"')

st2=dataset_funnel_2.pivot_table(index='session_id',values='source',aggfunc='first')\
.rename_axis(None, axis=1).reset_index(level = None)
st2=st2.query('source=="advert_open"')['session_id'].tolist()
step_2=dataset_funnel_2.query('session_id == @st2')['user_id'].nunique()
dataset_funnel_3=dataset_funnel_2.query('session_id == @st2').query('source != "advert_open"')

st3=dataset_funnel_3.pivot_table(index='session_id',values='source',aggfunc='first')\
.rename_axis(None, axis=1).reset_index(level = None)
st3=st3.query('source=="tips_show"')['session_id'].tolist()
step_3=dataset_funnel_3.query('session_id == @st3')['user_id'].nunique()
dataset_funnel_4=dataset_funnel_3.query('session_id == @st3').query('source != "tips_show"')


step_4=dataset_funnel_4['user_id'].nunique()

# %%
# строим воронку событий и считаем долю пользователей,которые проходят на следующий шаг воронки
fig = go.Figure(go.Funnel(
    y = ["map","advert_open", "tip_show", "show_contacts"],
    x = [step_1, step_2, step_3, step_4], textposition = "inside" ,textinfo = "value+percent previous")
               )
fig.update_layout(title='Воронка событий: map - tip_show - show_contacts')
fig.show();
# Out:
# <div>                            <div id="3b22ad56-a6a2-44b1-b528-6502a8980092" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b22ad56-a6a2-44b1-b528-6502a8980092")) {                    Plotly.newPlot(                        "3b22ad56-a6a2-44b1-b528-6502a8980092",                        [{"textinfo":"value+percent previous","textposition":"inside","x":[1142,310,259,11],"y":["map","advert_open","tip_show","show_contacts"],"type":"funnel"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fil
# ...

# %% [markdown]
# При построение последней воронки мы использовали большее количество шагов до достижения целевого действия. На первом этапе "просмотра карты" пришло 1142 человека, из них на этап "открыл карточки объявлени" перешли только 27%, но из этих 310 пользователей 84% перешли на следующий этап "увидел рекомендованные объявления" - 259 пользователей. И на целевое действие перешло только 11 пользователей- 4%. Из всех пришедших пользователей, до целевого действия дошел только 1%. Поэтому можно сделать вывод, что первая воронка __map - tip_show - show_contacts__ стала лучшей по абсолютным и относительным значениям.

# %% [markdown]
# #### Как различается длительность сессий с contacts_show и без него?

# %%
dataset_sankey.head()
# Out:
#    session_id          event_time event_name  \
# 0           1 2019-10-07 13:39:45  tips_show
# 1           2 2019-10-09 18:33:55        map
# 2           2 2019-10-09 18:40:28  tips_show
# 3           3 2019-10-21 19:52:30  tips_show
# 4           3 2019-10-21 19:53:38        map
#
#                                 user_id  duration
# 0  0001b1d5-b74a-4cbf-aeb0-7df5947bf349     596.0
# 1  0001b1d5-b74a-4cbf-aeb0-7df5947bf349     507.0
# 2  0001b1d5-b74a-4cbf-aeb0-7df5947bf349     507.0
# 3  0001b1d5-b74a-4cbf-aeb0-7df5947bf349     900.0
# 4  0001b1d5-b74a-4cbf-aeb0-7df5947bf349     900.0

# %%
# создаем файл, где будут сессии только с просмотром контактов
ses_with=dataset_sankey.query('event_name=="show_contacts"').drop_duplicates(['session_id']).reset_index()
print('с просмотром контактов')
print(ses_with['duration'].describe())
print('')
# из файла столбца сессиий файла ses_with делаем список
f=ses_with['session_id'].tolist()
# создаем файл, где будут сессии без просмотра контактов
ses_without=dataset_sankey.query('session_id!=@f').drop_duplicates(['session_id']).reset_index()
print('без просмотров контактов')
print(ses_without['duration'].describe())
# Out:
# с просмотром контактов
# count     1703.000000
# mean      1207.062830
# std       1591.906865
# min          0.000000
# 25%        141.000000
# 50%        655.000000
# 75%       1630.500000
# max      12545.000000
# Name: duration, dtype: float64
#
# без просмотров контактов
# count     8665.000000
# mean       687.298904
# std       1075.566397
# min          0.000000
# 25%          6.000000
# 50%        293.000000
# 75%        936.000000
# max      19319.000000
# Name: duration, dtype: float64

# %%
plt.figure(figsize=(12, 5))

ax1 = plt.subplot(1, 2, 1)
ses_with[['duration']].boxplot(ax=ax1)
plt.ylabel('Секунды')
plt.title('Диаграма размаха для длительности сессий \n с целевым действием');
ax2 = plt.subplot(1, 2, 2,sharey=ax1)
ses_without[['duration']].boxplot(ax=ax2)
plt.title('Диаграма размаха для длительности сессий \n без целевого действием');

# %% [markdown]
# По графику выше видно, что средняя длительность сессии с целевым действием больше, чем без него. Так же мы видим что верхний "ус" первой диаграмы находится на отметке примерно в 62 минуты, когда как для второй на 20 минут ниже. Для сессии без целевого действия так же есть выбросы более 5 часов.

# %% [markdown]
# ### Оценить, какие действия чаще совершают те пользователи, которые просматривают контакты:

# %% [markdown]
# В данном пунке нам нужно будет:
#
# - Рассчитать относительную частоту событий в разрезе двух групп пользователей - с contacts_show и без него.
#
# У нас уже есть файл ses_with, с сессиями в целевое действие. Пользователей из этого файла запишем в первую группу, остальных во вторую.

# %%
tm_1=ses_with.drop_duplicates(['user_id'])
tm_1=tm_1['user_id'].tolist()

# формируем таблицу (c просмотра контактов), в которой для каждого действия посчитаем частоту 
team_1=dataset_sankey.query('user_id==@tm_1')
# группируем team_1 по действиям, считаем количество 
team_1=team_1.pivot_table(index='event_name', values='user_id',aggfunc='count').sort_values('user_id')
# добавляем столбец с процентом
team_1['percent']=round(team_1['user_id']*100/sum(team_1['user_id']),2)
# удаляем "двухэтажные" названия 
team_1=team_1.rename_axis(None, axis=1).reset_index()
# оставляем нужные столбцы
team_1=team_1[['event_name','percent']]
# добавляем столбец со словом without для дальнейшего использования в группировке
team_1['name']='with'


# формируем таблицу  (без просмотром контактов), в которой для каждого действия посчитаем частоту 
team_2=dataset_sankey.query('user_id!=@tm_1 ')
team_2=team_2.pivot_table(index='event_name', values='user_id',aggfunc='count').sort_values('user_id')
team_2['percent']=round(team_2['user_id']*100/sum(team_2['user_id']),2)
team_2=team_2.rename_axis(None, axis=1).reset_index()
team_2=team_2[['event_name','percent']]
team_2['name']='without'


# соединяем две таблицы: одну под другой
table_w=pd.concat([team_2,team_1],sort=False,axis=0)
# группируем так, чтобы в дальнейшем, мы могли истользовать столбик name для 
# визуализации разных групп (с и без целевого действия)
table_w=table_w.pivot_table(index=['event_name','name'],values='percent',aggfunc='sum')
table_w=table_w.rename_axis(None, axis=1).reset_index()

# %%
# строим график
z=px.bar(table_w, x='event_name',y='percent',\
          barmode="group",text='percent',color='name',\
         title='Относительная частота событий в разрезе двух групп пользователей - с contacts_show и без него ',height=500,width=800)
z.update_xaxes(title_text='Названия действий')
z.update_yaxes(title_text='Процент')
z.show()
# Out:
# <div>                            <div id="82b4d55e-501b-4e02-8039-376f6ac6e2f2" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82b4d55e-501b-4e02-8039-376f6ac6e2f2")) {                    Plotly.newPlot(                        "82b4d55e-501b-4e02-8039-376f6ac6e2f2",                        [{"alignmentgroup":"True","hovertemplate":"name=with<br>event_name=%{x}<br>percent=%{text}<extra></extra>","legendgroup":"with","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"with","offsetgroup":"with","orientation":"v","showlegend":true,"text":[4.86,4.32,2.78,8.31,14.48,13.35,23.59,2.17,26.13],"textposition":"auto","x":["advert_open","contacts_call","favorites_add","map","photos_show","search","show_contacts","tips_click","tips_show"],"xaxis":"x","y
# ...

# %% [markdown]
# Если рассматривать такие датасеты, то в относительных величинах все событие без просмотра контактов производятся чаще, чем с целевым действием.
#
# Но нам следует убрать из датасета с целевым действие просмотр контактов и звонок, так как эти два действия забирают на себя большой объем всех действий.

# %%
team_1=dataset_sankey.query('user_id==@tm_1 and event_name!="show_contacts" and event_name!="contacts_call"')
team_1=team_1.pivot_table(index='event_name', values='user_id',aggfunc='count').sort_values('user_id')
team_1['percent']=round(team_1['user_id']*100/sum(team_1['user_id']),2)
team_1=team_1.rename_axis(None, axis=1).reset_index()
team_1=team_1[['event_name','percent']]
team_1['name']='with'


table_w=pd.concat([team_2,team_1],sort=False,axis=0)
table_w=table_w.pivot_table(index=['event_name','name'],values='percent',aggfunc='sum')
table_w=table_w.rename_axis(None, axis=1).reset_index()

# %%
# строим график
z=px.bar(table_w, x='event_name',y='percent',\
          barmode="group",text='percent',color='name',\
         title='Относительная частота событий в разрезе двух групп пользователей - с contacts_show и без него',height=500,width=800)
z.update_xaxes(title_text='Названия действий')
z.update_yaxes(title_text='Процент')
z.show()
# Out:
# <div>                            <div id="8834d114-3e22-44ef-a7e2-ead80d32bc1d" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8834d114-3e22-44ef-a7e2-ead80d32bc1d")) {                    Plotly.newPlot(                        "8834d114-3e22-44ef-a7e2-ead80d32bc1d",                        [{"alignmentgroup":"True","hovertemplate":"name=with<br>event_name=%{x}<br>percent=%{text}<extra></extra>","legendgroup":"with","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"with","offsetgroup":"with","orientation":"v","showlegend":true,"text":[6.74,3.86,11.53,20.08,18.52,3.02,36.24],"textposition":"auto","x":["advert_open","favorites_add","map","photos_show","search","tips_click","tips_show"],"xaxis":"x","y":[6.74,3.86,11.53,20.08,18.52,3.02,36.24]
# ...

# %% [markdown]
# Если мы исключаем эти 2 события, то получается, что другие события происходят практически с одинаковой частотой для обеих групп. Сильная разница только у действия "просмотр фотографий", для сессий с целевым действием - 20%, без целевого 14%.

# %% [markdown]
# ## Проверка гипотез
#
# Мы будем проверять три гипотезы:
#
#  * Одни пользователи совершают действия tips_show и tips_click , другие — только tips_show . Проверить гипотезу: конверсия в просмотры контактов различается у этих двух групп;
#  * Проверить гипотезу: конверсия в просмотры контактов вечерних сессиий (например с 19:00-6:00) выше, чем дневных сессий;
#  * Проверить гипотезу: конверсия пользователей пришедших с Яндекса, с Гугл и других источников разная.

# %% [markdown]
# ### Одни пользователи совершают действия tips_show и tips_click , другие — только tips_show . Проверить гипотезу: конверсия в просмотры контактов различается у этих двух групп;

# %% [markdown]
# Одни пользователи совершают действия tips_show и tips_click , другие — только tips_show . Первую группу будем называть t1, а вторую t2.
#
# __Сформулируем гипотезы:__
#
# __Н0: Статически значимых различий в конверсии в просмотры между группами t1 и t2 нет__
#
# __Н1: Статически значимые различия в конверсии в просмотры между группами t1 и t2 есть__
#
# Для проверки гипотезы нам подходит метод - проверка гипотезы о равенстве долей.
#
# Напишем функцию test(successes, trials, alpha), которая проверит будут ли доли разными или нет. Критический уровень статистической значимости будем брать равным 0.05, для наших исседований будет достаточно.

# %% [markdown]
# Бедум использовать файл df_comp

# %%
df_comp.head()
# Out:
#    session_id          event_time                               user_id  \
# 0           1 2019-10-07 13:39:45  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 1           2 2019-10-09 18:33:55  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 2           2 2019-10-09 18:40:28  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 3           3 2019-10-21 19:52:30  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 4           3 2019-10-21 19:53:38  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
#
#    duration  step     source     target
# 0     596.0     1  tips_show        NaN
# 1     507.0     1        map  tips_show
# 2     507.0     2  tips_show        NaN
# 3     900.0     1  tips_show        map
# 4     900.0     2        map        NaN

# %%
# сгруппируем его по пользователелям, в колонках посчитаем сколько раз этот пользователь совершил каждое действие
t=df_comp.pivot_table(index='user_id', columns='source', values='session_id',aggfunc='count')
t=t.rename_axis(None, axis=1).reset_index()
# оставим только столбик с пользователем с нужными нам действиями
t=t[['user_id','tips_show','tips_click','show_contacts']]
# пропуски заполним нулями для упрощения
t=t.fillna(0)
t.head()
# Out:
#                                 user_id  tips_show  tips_click  show_contacts
# 0  0001b1d5-b74a-4cbf-aeb0-7df5947bf349        4.0         0.0            0.0
# 1  00157779-810c-4498-9e05-a1e9e3cedf93        0.0         0.0            4.0
# 2  00463033-5717-4bf1-91b4-09183923b9df        0.0         0.0            0.0
# 3  004690c3-5a84-4bb7-a8af-e0c8f8fca64e        2.0         0.0            0.0
# 4  00551e79-152e-4441-9cf7-565d7eb04090        0.0         0.0            2.0

# %% [markdown]
# Далее разделим этот файл на два: те кто вершили оба шага tips_show+tips_click - будет первой группой t_1, те кто только один шаг tips_show - будет второй группой t_2.

# %%
#пользователи которые совершали оба шага
t_1=t.query('tips_show!=0 and tips_click!=0')
t_1.head()
# Out:
#                                  user_id  tips_show  tips_click  show_contacts
# 21  01147bf8-cd48-49c0-a5af-3f6eb45f8262        1.0         1.0            0.0
# 32  01b4ca51-930d-4518-aa09-8a8c35e1d9cc        1.0         1.0            0.0
# 46  02e7c193-842b-4995-b67a-8c87ac0f29bb        1.0         1.0            0.0
# 75  04ee0c31-3c77-49f8-81d2-bbfe9fe2cde8        1.0         1.0            0.0
# 99  0656a1d1-9032-43ae-b936-11e41526eeff        1.0         1.0            0.0

# %%
con_1=t_1.query('show_contacts!=0')['show_contacts'].count()/t_1['show_contacts'].count()
con_1=con_1.round(2)
print('Количество уникальных пользователей совершивших 2 действия=',t_1['show_contacts'].count())
print('Количество уникальных пользователей совершивших 2 действия и целевое =',t_1.query('show_contacts!=0')['show_contacts'].count())
print('Конверсия для совершивших 2 действия=',con_1)
# Out:
# Количество уникальных пользователей совершивших 2 действия= 287
# Количество уникальных пользователей совершивших 2 действия и целевое = 86
# Конверсия для совершивших 2 действия= 0.3

# %%
#пользователи совершиевшие только 1 действие
t_2=t.query('tips_show!=0 and tips_click==0')

con_2=t_2.query('show_contacts!=0')['show_contacts'].count()/t_2['show_contacts'].count()
con_2=con_2.round(2)

print('Количество уникальных пользователей совершивших 1 действие=',t_2['show_contacts'].count())
print('Количество уникальных пользователей совершивших 1 действие и перешедших в контакты=',t_2.query('show_contacts!=0')['show_contacts'].count())
print('Конверчия для совершивших 1 действие=',con_2)
# Out:
# Количество уникальных пользователей совершивших 1 действие= 2514
# Количество уникальных пользователей совершивших 1 действие и перешедших в контакты= 420
# Конверчия для совершивших 1 действие= 0.17

# %%
# функция проверки гипотезы о равенстве долей

def test(successes, trials):  


    alpha = 0.05
    successes = successes # кол-во успешных попыток [группа1, группа2]
    trials = trials # всего попыток [группа1, группа2]

    # пропорция успехов в первой группе:
    p1 = successes[0]/trials[0]

    # пропорция успехов во второй группе:
    p2 = successes[1]/trials[1]

    # пропорция успехов в комбинированном датасете:
    p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

    # разница пропорций в датасетах
    difference = p1 - p2


    # считаем статистику в ст.отклонениях стандартного нормального распределения
    z_value = difference / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1) 


    # считаем статистику в ст.отклонениях стандартного нормального распределения
    z_value = difference / mth.sqrt(
        p_combined * (1 - p_combined) * (1 / trials[0] + 1 / trials[1])
    )

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1)

    p_value = (1 - distr.cdf(abs(z_value))) * 2

    print('p-значение: ', p_value)

    if p_value < alpha:
        print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
    else:
        print(
            'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
        )

    
successes = [t_1.query('show_contacts!=0')['show_contacts'].count(), t_2.query('show_contacts!=0')['show_contacts'].count()]
trials = [t_1['show_contacts'].count(), t_2['show_contacts'].count()]

test(successes, trials)
# Out:
# p-значение:  3.181504659721668e-08
# Отвергаем нулевую гипотезу: между долями есть значимая разница

# %% [markdown]
# Это значит, что конверсия в просмотры контактов различается у этих двух групп.

# %% [markdown]
# ###  Проверить гипотезу: конверсия в просмотры контактов вечерних сессиий (например с 19:00-6:00) выше, чем дневных сессий

# %% [markdown]
# Поделим все сессии на "дневные" и "вечерние". Первую группу будем называть t1, а вторую t2.
#
# __Сформулируем гипотезы:
#
# __Н0: Статически значимых различий в конверсии в просмотры между группами t1 и t2 нет__
#
# __Н1: Статически значимые различия в конверсии в просмотры между группами t1 и t2 есть__
#
# Для проверки гипотезы нам подходит метод - проверка гипотезы о равенстве долей.
#
# Вечерней сессией будем считать сессию, начало которой было между 19:00 и 6:00. Будем использовать файлы df_comp и dataset_dur.

# %%
# оставим в файле dataset_dur только столбики с началом сессии и номер сессии
dataset_dur=dataset_dur[['session_id','first']]

# %%
# объединяем эти два файла и добавляем новый столбец с часом начала сессии
t=df_comp.merge(dataset_dur,on='session_id')
t['hour']=t['first'].dt.hour
t.head()
# Out:
#    session_id          event_time                               user_id  \
# 0           1 2019-10-07 13:39:45  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 1           2 2019-10-09 18:33:55  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 2           2 2019-10-09 18:40:28  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 3           3 2019-10-21 19:52:30  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 4           3 2019-10-21 19:53:38  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
#
#    duration  step     source     target               first  hour
# 0     596.0     1  tips_show        NaN 2019-10-07 13:39:45    13
# 1     507.0     1        map  tips_show 2019-10-09 18:33:55    18
# 2     507.0     2  tips_show        NaN 2019-10-09 18:33:55    18
# 3     900.0     1  tips_show        map 2019-10-21 19:52:30    19
# 4     900.0     2        map        NaN 2019-10-21 19:52:30    19

# %%
# выделяем дневные сессии
t_1=t.query('hour>=7 and hour<=18')
# группируем дневные сессии, для каждой сессии определяем, каким действием она закончилась
t_11=t_1.pivot_table(index='session_id', values='source',aggfunc='last')\
.rename_axis(None, axis=1).reset_index()
# отбираем удачные (дошли до просмотра контактов) сессии
t_11=t_11.query('source=="show_contacts"')

# %%
con_1=round(len(t_11)/t_1['session_id'].nunique(),2)
print('Количество дневных сессий =',t_1['session_id'].nunique())
print('Количество дневных удачных сессий =',len(t_11))
print('Конверсия для дневных сессий=',con_1)
# Out:
# Количество дневных сессий = 6895
# Количество дневных удачных сессий = 734
# Конверсия для дневных сессий= 0.11

# %%
# отбираем вечерние сессии
day_ses=t_1['session_id'].tolist()
t_2=t.query('session_id != @day_ses')
t_22=t_2.pivot_table(index='session_id', values='source',aggfunc='last')\
.rename_axis(None, axis=1).reset_index()
t_22=t_22.query('source=="show_contacts"')

# %%
con_2=round(len(t_22)/t_2['session_id'].nunique(),2)
print('Количество вечерних сессий =',t_2['session_id'].nunique())
print('Количество вечерних удачных сессий =',len(t_22))
print('Конверсия для вечерних сессий=',con_2)
# Out:
# Количество вечерних сессий = 3473
# Количество вечерних удачных сессий = 273
# Конверсия для вечерних сессий= 0.08

# %%
# проверяем гипотезу
successes = [len(t_22), len(t_11)]
trials = [t_2['session_id'].nunique(), t_1['session_id'].nunique()]

test(successes, trials)
# Out:
# p-значение:  6.202265985466582e-06
# Отвергаем нулевую гипотезу: между долями есть значимая разница

# %% [markdown]
# Это значит, что конверсия в просмотры контактов различается у этих двух групп. А расчет конверсии показал, что выше конверсия у дневных сессий.

# %% [markdown]
# ###  Проверить гипотезу: конверсия пользователей пришедших с Яндекса, с Гугл и других источников разная.

# %% [markdown]
# Здесь будут сравниваться 3 группы контактов, и сначала мы долны получить эти 3 группы. Для это файлы df_comp и sources соеденим в одну таблицу.

# %%
df_comp=df_comp.rename(columns={'source':'event_name'})
t=df_comp.merge(sources, on='user_id')
t.head()
# Out:
#    session_id          event_time                               user_id  \
# 0           1 2019-10-07 13:39:45  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 1           2 2019-10-09 18:33:55  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 2           2 2019-10-09 18:40:28  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 3           3 2019-10-21 19:52:30  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
# 4           3 2019-10-21 19:53:38  0001b1d5-b74a-4cbf-aeb0-7df5947bf349
#
#    duration  step event_name     target source
# 0     596.0     1  tips_show        NaN  other
# 1     507.0     1        map  tips_show  other
# 2     507.0     2  tips_show        NaN  other
# 3     900.0     1  tips_show        map  other
# 4     900.0     2        map        NaN  other

# %%
# соберем первую группу пользоваталей, которые пришли через яндекс
t_1=t.query('source=="yandex"')

t_1=t_1.pivot_table(index='user_id', columns='event_name', values='session_id',aggfunc='count')
t_1=t_1.rename_axis(None, axis=1).reset_index()
t_1=t_1[['user_id','show_contacts']]
t_1=t_1.fillna(0)

# %%
con_1=t_1.query('show_contacts!=0')['show_contacts'].count()/t_1['show_contacts'].count()
con_1=con_1.round(2)
print('Количество уникальных яндекс пользователей =',t_1['show_contacts'].count())
print('Количество уникальных яндекс пользователей и перешедших в контакты=',t_1.query('show_contacts!=0')['show_contacts'].count())
print('Конверсия для яндекс пользователей=',con_1)
# Out:
# Количество уникальных яндекс пользователей = 1934
# Количество уникальных яндекс пользователей и перешедших в контакты= 475
# Конверсия для яндекс пользователей= 0.25

# %%
# соберем вторую группу пользоваталей, которые пришли через гугл
t_2=t.query('source=="google"')

t_2=t_2.pivot_table(index='user_id', columns='event_name', values='session_id',aggfunc='count')
t_2=t_2.rename_axis(None, axis=1).reset_index()
t_2=t_2[['user_id','show_contacts']]
t_2=t_2.fillna(0)

# %%
con_2=t_2.query('show_contacts!=0')['show_contacts'].count()/t_2['show_contacts'].count()
con_2=con_2.round(2)
print('Количество уникальных гугл пользователей =',t_2['show_contacts'].count())
print('Количество уникальных гугл пользователей и перешедших в контакты=',t_2.query('show_contacts!=0')['show_contacts'].count())
print('Конверсия для гугл пользователей=',con_2)
# Out:
# Количество уникальных гугл пользователей = 1129
# Количество уникальных гугл пользователей и перешедших в контакты= 270
# Конверсия для гугл пользователей= 0.24

# %%
# соберем третью группу пользоваталей, которые пришли через другие источники
t_3=t.query('source=="other"')

t_3=t_3.pivot_table(index='user_id', columns='event_name', values='session_id',aggfunc='count')
t_3=t_3.rename_axis(None, axis=1).reset_index()
t_3=t_3[['user_id','show_contacts']]
t_3=t_3.fillna(0)

# %%
con_3=t_3.query('show_contacts!=0')['show_contacts'].count()/t_3['show_contacts'].count()
con_3=con_3.round(2)
print('Количество уникальных другие_источники пользователей =',t_3['show_contacts'].count())
print('Количество уникальных другие_источники пользователей и перешедших в контакты=',t_3.query('show_contacts!=0')['show_contacts'].count())
print('Конверсия для другие_источники пользователей=',con_3)
# Out:
# Количество уникальных другие_источники пользователей = 1230
# Количество уникальных другие_источники пользователей и перешедших в контакты= 225
# Конверсия для другие_источники пользователей= 0.18

# %% [markdown]
# __Проведем проверку гипотезы:__

# %%
#между яндексом и гуглом
successes = [t_1.query('show_contacts!=0')['show_contacts'].count(), t_2.query('show_contacts!=0')['show_contacts'].count()]
trials = [t_1['show_contacts'].count(), t_2['show_contacts'].count()]

test(successes, trials)
# Out:
# p-значение:  0.6878866543495663
# Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными

# %%
#между яндексом и другими
successes = [t_1.query('show_contacts!=0')['show_contacts'].count(), t_3.query('show_contacts!=0')['show_contacts'].count()]
trials = [t_1['show_contacts'].count(), t_3['show_contacts'].count()]

test(successes, trials)
# Out:
# p-значение:  3.466514676087051e-05
# Отвергаем нулевую гипотезу: между долями есть значимая разница

# %%
#между гуглом и другими
successes = [t_2.query('show_contacts!=0')['show_contacts'].count(), t_3.query('show_contacts!=0')['show_contacts'].count()]
trials = [t_2['show_contacts'].count(), t_3['show_contacts'].count()]

test(successes, trials)
# Out:
# p-значение:  0.0008079788739550064
# Отвергаем нулевую гипотезу: между долями есть значимая разница

# %% [markdown]
# Получается, что нулевую гипотезу нельзя отвергнуть для групп яндекс и гугл, конверсия у них равна. А вот для остальных групп конверсии будут различаться.

# %% [markdown]
# ## Вывод

# %% [markdown]
# __Мы провели анализ поведения пользователей мобильного приложения "Ненужные вещи", целью которого было:__
#  * Управление вовлеченностью клиентов (адаптация приложения по целевой и смежной аудитории) будет актуально только на основе данных о поведении пользователей;
#  * Получить на основе поведения пользователей гипотезы о том как можно было бы улучшить приложение с точки зрения пользовательского опыта.
#
# Для анализа был предоставлен файл, содержащий id пользователей, название действий и время их совершения.Период наблюдения составил 4 недели - с 7 октября 2019 по 3 ноября 2019.
#
# __Мы провели предработку и перешли к исследовательскому анализу:__
# 1. Посчитали количество уникальных пользователей, использовавших наше приложение в течении дня (DAU) и выяснили, что в первый день в приложение зашли 204 пользователя, на 6 день мы увидили самое низкое число пользователей - 178, а на 17 день максимальное - 352. Несмотря на некоторые падения, в среднем этот показатель рос на всем периоде наблюдений.
# 2. Посчитали количество новых пользователей каждый день (DNUA), и здесь в целом график стремился к постоянному числу (примерно 155), но в последнюю неделю наблюдений произошло снижение.
# 3. Оценивали retention rate, с моментом анализа - 3 ноября и горизонтов в 14 дней и выяснили, что удержание практически для всех когорт имеет одинаковую тенденцию, но есть несколько выбивающихся значений. Например:
#    * У пользоваталей от 12 октября на второй день наблюдений был резкий скачок до 0.16, а потом не менее резкий спад, на третй день удержание ровнялось 0.05. Но с 5 по 10 день наблюдений удержание для этой когорты было выше, чем у всех остальных;
#    * У пользователей от 16 октября с первого по третий день удержание падало и достигло 0.03, далее увеличилось до 0.06, но не поднималось выше этого показателя на протяжении всего периода наблюдений;
#    * Самое низкое удержание достигается у когорты от 11 октября на 8 день - менее 0.02. Что интересно, только у этой когорты именно в этот день удержание резко падает, когда у остальных либо увеличивается, либо остается прежним;
# 4. Так же мы посчитали конверсию для новых посетителей посмотревших контакты. На первый день лайфтайма конверсия составляла 0.18, а на 14 день чуть выше 0.22. Конверсия увеличивалась, но всего на 0.04% пункта.
# 5. Посчитали, что средняя продолжительность сессий составляет 534 секунды и меняется в зависиммости от дня недели. В выходные и понедельник сессии примерно по 550 секунд, далее идет снижение, и во вторник и среду сессии длятся 500 секунд, и далее опять идет повышение.
# 6. Посчитали среднее число сессий на пользователя за день - 346. В начале запуска приложения в день в среднем было около 250 сессии. В первый и 6 день сессий было еще меньше - 210-220. После недельного использования приложения сессий стало больше и практически на всем периоде это число выше среднего. Так же по графику видны недельные "ритмы", как и для средней продолжительности, т.е. в среду и четверг самые низкие показателя, далее они растут к выходным и во вторник происходит уменьшение.
# 7. Проанализировали источники, через которые пришли пользователи и выяснили, что пользователей, пришедших из яндекса практически в 2 раза больше чем, пользователей пришедших из гугла и других - 45% и у этих пользователей лучшие показатели конверсии и удержания. Меньше всего пришло из гугл - 26%.
#
# Далее необходимо было проанализировать __связь целевого события — просмотра контактов — и других действий пользователей__. Для этого мы построили диаграму Сэнкея, чтобы выделить основные сценарии, которые приводят к просмотру контактов.
#
# В результате полученых сценариев, мы построили __воронки событий__ со следующими параметрами:
# 1. Первая воронка: 9,5% от первоначальных пользоваталей посмотрели контакты
#    * __map__  - 1149 пользователей
#    * __tips_show__ - 978 пользователей
#    * __show_contacts__ - 110 пользователей
#
# 2. Вторая воронка: 4% от первоначальных пользоваталей посмотрели контакты
#    * __photos_show__  - 1566 пользователей
#    * __search__ - 460 пользователей
#    * __show_contacts__ - 57 пользователей
#
# 3. Третья воронка: 1% от первоначальных пользоваталей посмотрели контакты
#    * __map__  - 1142 пользователей
#    * __advert_open__ - 310 пользователей
#    * __tips_show__ - 259 пользователей
#    * __show_contacts__ - 11 пользователей
#
# Анализирую __продолжительность сессии с целевым действием и без него__, выяснили что сессии с целевым действием дляться дольше примерно в 2 раза.
#
# Оценивали, какие __действия чаще совершают те пользователи, которые просматривают контакты__, а именно рассчивали относительную частоту событий в разрезе двух групп пользователей - с contacts_show и без него. Выяснили, что в целом эти 2 группы пользователей с одинаковой частотой совершали все действия, кроме действия photos_show. Для группы с contacts_show действие photos_show происходит чаще на 6%, чем в другой группе.
#
# И в последним пунктом мы __проверяли следующие гипотезы:__
# 1. Одни пользователи совершают действия tips_show и tips_click , другие — только tips_show . Конверсия в просмотры контактов различается у этих двух групп. При проверке гипотезы выяснили, что статически значимые различия есть. Конверсия для первой группы = 0.3, а для второй = 0.17;
#
# 2. Конверсия в просмотры контактов вечерних сессиий (например с 19:00-6:00) выше, чем дневных сессий. Получили что статически значимые различия есть. Конверсия для дневных сессий = 0.11 , а для ночных = 0.08;
#
# 3. Конверсия пользователей пришедших с Яндекса, с Гугл и других источников разная. Выяснили следующее: статически значимых различий нет у групп Яндекса и Гугла, но есть между группами Яндекс/Другие и Гугл/Другие. Коверсия для Яндекса=0.25, для Гугл=0.24 и для Других=0.18.
#
#
#
# В результате анализа можно сделать слудующие рекомендации:
# Необходимо привлекать новых пользователей через действия, которые чаще приводят к целевому действию, а именно tips_show в связке с tips_click, photos_show и search. Поработотать с другими связками, например map и photos_show. Возможно, действие advert_open вообще не нужный шаг.

# %% [markdown]
# # Презентация
# https://drive.google.com/file/d/1xy_F_WpbPdg3vVHutMjZph_u3wUGRRn7/view?usp=sharing

# %% [markdown]
# # Дашборд
# https://public.tableau.com/views/final_16953231195050/Dashboard2?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link
